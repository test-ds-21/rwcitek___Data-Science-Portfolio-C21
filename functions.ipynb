# %% [markdown]
# <a href="https://colab.research.google.com/github/rwcitek/Data-Science-Portfolio-C21/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Functions
# - foundational
#   - print
#   - type
#   - help
#
# - list functions
#   - range
#   - enumerate
#   - zip
#   - reversed
#   - len
#   - sorted
